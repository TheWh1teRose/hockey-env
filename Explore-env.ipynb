# %%
import numpy as np
import hockey.hockey_env as h_env
import gymnasium as gym
from importlib import reload
import time

# %%
env = h_env.HockeyEnv()

# %%
obs, info = env.reset()
obs_agent2 = env.obs_agent_two()
_ = env.render()

# %%
obs, info = env.reset()
obs_agent2 = env.obs_agent_two()

# %%
env.render(mode="human")
# 
a1 = np.array([1.0, 0.0, 0.0, 1.0])
a2 = np.random.uniform(-1,1,4)    
obs, r, d, t, info = env.step(np.hstack([a1,a2]))    
obs_agent2 = env.obs_agent_two()

print("a1: ", a1)
print("a2: ", a2)

print("obs: ", obs)
print("r: ", r)
print("d: ", d)
print("t: ", t)
print("info: ", info)
# Out:
# a1:  [1. 0. 0. 1.]
# a2:  [ 0.84535314 -0.43373691 -0.73775178 -0.18227444]
# obs:  [-4.89079475e-01  1.25513077e-02  1.03139989e-01 -4.39865887e-01
#  -8.65137224e-07  1.37989581e-01  3.15542507e+00  1.63608789e+00
#   8.70267987e-01 -1.36801779e-01  1.07940280e+00 -2.85020709e+00
#   1.05367146e+01  7.29136467e-02  2.26288681e+01  1.30791351e-01
#   0.00000000e+00  0.00000000e+00]
# r:  10.0
# d:  True
# t:  False
# info:  {'winner': 1, 'reward_closeness_to_puck': 0.0, 'reward_touch_puck': 0.0, 'reward_puck_direction': 0.0036206188964843754}
